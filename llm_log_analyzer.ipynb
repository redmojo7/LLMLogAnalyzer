# %% [markdown]
# # Llama3 RAG Chatbot

# %%
#!pip install --upgrade transformers

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
# Out:
# zsh:1: command not found: nvidia-smi

# %% [markdown]
# ## 1. Install Packages

# %%
# !pip install llama-index
# !pip install llama_index.embeddings.huggingface
# !pip install llama-index-llms-huggingface
# !pip install llama-index-llms-groq
# !pip install gradio
#!pip install logpai
# Out:
# Requirement already satisfied: llama-index in /opt/homebrew/anaconda3/lib/python3.12/site-packages (0.11.16)
# Requirement already satisfied: llama-index-agent-openai<0.4.0,>=0.3.4 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from llama-index) (0.3.4)
# Requirement already satisfied: llama-index-cli<0.4.0,>=0.3.1 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from llama-index) (0.3.1)
# Requirement already satisfied: llama-index-core<0.12.0,>=0.11.16 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from llama-index) (0.11.16)
# Requirement already satisfied: llama-index-embeddings-openai<0.3.0,>=0.2.4 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from llama-index) (0.2.5)
# Requirement already satisfied: llama-index-indices-managed-llama-cloud>=0.3.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from llama-index) (0.4.0)
# Requirement already satisfied: llama-index-legacy<0.10.0,>=0.9.48 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from llama-index) (0.9.48.post3)
# Requirement already satisfied: llama-index-llms-openai<0.3.0,>=0.2.10 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from llama-index) (0.2.11)
# Requirement already satisfied: llama-index-multi-modal-llms-openai<0.3.0,>=0.2.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from llama-index) (0.2.2)
# Requirement already satisfied: llama-index-program-openai<0.3.0,>=0.2.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from llama-index) (0.2.0)
# Requirement already satisfied: llama-index-question-gen-openai<0.3.0,>=0.2.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from llama-index) (0.2.0)
# Requirement already satisfied: llama-index-readers-file<0.3.0,>=0.2.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from llama-index) (0.2.2)
# Requirement already satisfied: llama-index-readers-llama-parse>=0.3.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from llama-index) (0.3.0)
# Requirement already satisfied: nltk>3.8.1 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from llama-index) (3.9.1)
# Requirement already satisfied: openai>=1.14.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from llama-index-agent-openai<0.4.0,>=0.3.4->llama-index) (1.51.0)
# Requirement already satisfied: PyYAML>=6.0.1 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.16->llama-index) (6.0.1)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.12.0,>=0.11.16->llama-index) (2.0.30)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.16->llama-index) (3.9.5)
# Requirement already satisfied: dataclasses-json in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.16->llama-index) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.16->llama-index) (1.2.14)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.16->llama-index) (1.0.8)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.16->llama-index) (2024.3.1)
# Requirement already satisfied: httpx in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.16->llama-index) (0.27.2)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.16->llama-index) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.16->llama-index) (3.2.1)
# Requirement already satisfied: numpy<2.0.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.16->llama-index) (1.26.4)
# Requirement already satisfied: pillow>=9.0.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.16->llama-index) (10.3.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.16->llama-index) (2.9.2)
# Requirement already satisfied: requests>=2.31.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.16->llama-index) (2.32.2)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.2.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.16->llama-index) (8.2.2)
# Requirement already satisfied: tiktoken>=0.3.3 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.16->llama-index) (0.8.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.16->llama-index) (4.66.4)
# Requirement already satisfied: typing-extensions>=4.5.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.16->llama-index) (4.11.0)
# Requirement already satisfied: typing-inspect>=0.8.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.16->llama-index) (0.9.0)
# Requirement already satisfied: wrapt in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.16->llama-index) (1.14.1)
# Requirement already satisfied: llama-cloud>=0.0.11 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from llama-index-indices-managed-llama-cloud>=0.3.0->llama-index) (0.1.2)
# Requirement already satisfied: pandas in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from llama-index-legacy<0.10.0,>=0.9.48->llama-index) (2.2.2)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.12.3 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from llama-index-readers-file<0.3.0,>=0.2.0->llama-index) (4.12.3)
# Requirement already satisfied: pypdf<5.0.0,>=4.0.1 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from llama-index-readers-file<0.3.0,>=0.2.0->llama-index) (4.3.1)
# Requirement already satisfied: striprtf<0.0.27,>=0.0.26 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from llama-index-readers-file<0.3.0,>=0.2.0->llama-index) (0.0.26)
# Requirement already satisfied: llama-parse>=0.5.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from llama-index-readers-llama-parse>=0.3.0->llama-index) (0.5.7)
# Requirement already satisfied: click in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from nltk>3.8.1->llama-index) (8.1.7)
# Requirement already satisfied: joblib in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from nltk>3.8.1->llama-index) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from nltk>3.8.1->llama-index) (2023.10.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.16->llama-index) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.16->llama-index) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.16->llama-index) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.16->llama-index) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.16->llama-index) (1.9.3)
# Requirement already satisfied: soupsieve>1.2 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from beautifulsoup4<5.0.0,>=4.12.3->llama-index-readers-file<0.3.0,>=0.2.0->llama-index) (2.5)
# Requirement already satisfied: anyio in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from httpx->llama-index-core<0.12.0,>=0.11.16->llama-index) (4.2.0)
# Requirement already satisfied: certifi in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from httpx->llama-index-core<0.12.0,>=0.11.16->llama-index) (2024.6.2)
# Requirement already satisfied: httpcore==1.* in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from httpx->llama-index-core<0.12.0,>=0.11.16->llama-index) (1.0.6)
# Requirement already satisfied: idna in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from httpx->llama-index-core<0.12.0,>=0.11.16->llama-index) (3.7)
# Requirement already satisfied: sniffio in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from httpx->llama-index-core<0.12.0,>=0.11.16->llama-index) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from httpcore==1.*->httpx->llama-index-core<0.12.0,>=0.11.16->llama-index) (0.14.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from openai>=1.14.0->llama-index-agent-openai<0.4.0,>=0.3.4->llama-index) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from openai>=1.14.0->llama-index-agent-openai<0.4.0,>=0.3.4->llama-index) (0.5.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.0->llama-index-core<0.12.0,>=0.11.16->llama-index) (0.6.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.0->llama-index-core<0.12.0,>=0.11.16->llama-index) (2.23.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from requests>=2.31.0->llama-index-core<0.12.0,>=0.11.16->llama-index) (2.0.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from requests>=2.31.0->llama-index-core<0.12.0,>=0.11.16->llama-index) (2.2.2)
# Requirement already satisfied: greenlet!=0.4.17 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.12.0,>=0.11.16->llama-index) (3.0.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from typing-inspect>=0.8.0->llama-index-core<0.12.0,>=0.11.16->llama-index) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from dataclasses-json->llama-index-core<0.12.0,>=0.11.16->llama-index) (3.22.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from pandas->llama-index-legacy<0.10.0,>=0.9.48->llama-index) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from pandas->llama-index-legacy<0.10.0,>=0.9.48->llama-index) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from pandas->llama-index-legacy<0.10.0,>=0.9.48->llama-index) (2023.3)
# Requirement already satisfied: packaging>=17.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.12.0,>=0.11.16->llama-index) (23.2)
# Requirement already satisfied: six>=1.5 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas->llama-index-legacy<0.10.0,>=0.9.48->llama-index) (1.16.0)
# Requirement already satisfied: llama_index.embeddings.huggingface in /opt/homebrew/anaconda3/lib/python3.12/site-packages (0.3.1)
# Requirement already satisfied: huggingface-hub>=0.19.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from huggingface-hub[inference]>=0.19.0->llama_index.embeddings.huggingface) (0.23.5)
# Requirement already satisfied: llama-index-core<0.12.0,>=0.11.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from llama_index.embeddings.huggingface) (0.11.16)
# Requirement already satisfied: sentence-transformers>=2.6.1 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from llama_index.embeddings.huggingface) (3.1.1)
# Requirement already satisfied: filelock in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama_index.embeddings.huggingface) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama_index.embeddings.huggingface) (2024.3.1)
# Requirement already satisfied: packaging>=20.9 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama_index.embeddings.huggingface) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama_index.embeddings.huggingface) (6.0.1)
# Requirement already satisfied: requests in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama_index.embeddings.huggingface) (2.32.2)
# Requirement already satisfied: tqdm>=4.42.1 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama_index.embeddings.huggingface) (4.66.4)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama_index.embeddings.huggingface) (4.11.0)
# Requirement already satisfied: aiohttp in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from huggingface-hub[inference]>=0.19.0->llama_index.embeddings.huggingface) (3.9.5)
# Requirement already satisfied: minijinja>=1.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from huggingface-hub[inference]>=0.19.0->llama_index.embeddings.huggingface) (2.2.0)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.12.0,>=0.11.0->llama_index.embeddings.huggingface) (2.0.30)
# Requirement already satisfied: dataclasses-json in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama_index.embeddings.huggingface) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama_index.embeddings.huggingface) (1.2.14)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama_index.embeddings.huggingface) (1.0.8)
# Requirement already satisfied: httpx in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama_index.embeddings.huggingface) (0.27.2)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama_index.embeddings.huggingface) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama_index.embeddings.huggingface) (3.2.1)
# Requirement already satisfied: nltk>3.8.1 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama_index.embeddings.huggingface) (3.9.1)
# Requirement already satisfied: numpy<2.0.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama_index.embeddings.huggingface) (1.26.4)
# Requirement already satisfied: pillow>=9.0.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama_index.embeddings.huggingface) (10.3.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama_index.embeddings.huggingface) (2.9.2)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.2.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama_index.embeddings.huggingface) (8.2.2)
# Requirement already satisfied: tiktoken>=0.3.3 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama_index.embeddings.huggingface) (0.8.0)
# Requirement already satisfied: typing-inspect>=0.8.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama_index.embeddings.huggingface) (0.9.0)
# Requirement already satisfied: wrapt in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama_index.embeddings.huggingface) (1.14.1)
# Requirement already satisfied: transformers<5.0.0,>=4.38.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from sentence-transformers>=2.6.1->llama_index.embeddings.huggingface) (4.45.1)
# Requirement already satisfied: torch>=1.11.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from sentence-transformers>=2.6.1->llama_index.embeddings.huggingface) (2.4.1)
# Requirement already satisfied: scikit-learn in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from sentence-transformers>=2.6.1->llama_index.embeddings.huggingface) (1.4.2)
# Requirement already satisfied: scipy in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from sentence-transformers>=2.6.1->llama_index.embeddings.huggingface) (1.13.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from aiohttp->huggingface-hub[inference]>=0.19.0->llama_index.embeddings.huggingface) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from aiohttp->huggingface-hub[inference]>=0.19.0->llama_index.embeddings.huggingface) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from aiohttp->huggingface-hub[inference]>=0.19.0->llama_index.embeddings.huggingface) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from aiohttp->huggingface-hub[inference]>=0.19.0->llama_index.embeddings.huggingface) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from aiohttp->huggingface-hub[inference]>=0.19.0->llama_index.embeddings.huggingface) (1.9.3)
# Requirement already satisfied: click in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from nltk>3.8.1->llama-index-core<0.12.0,>=0.11.0->llama_index.embeddings.huggingface) (8.1.7)
# Requirement already satisfied: joblib in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from nltk>3.8.1->llama-index-core<0.12.0,>=0.11.0->llama_index.embeddings.huggingface) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from nltk>3.8.1->llama-index-core<0.12.0,>=0.11.0->llama_index.embeddings.huggingface) (2023.10.3)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.0->llama-index-core<0.12.0,>=0.11.0->llama_index.embeddings.huggingface) (0.6.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.0->llama-index-core<0.12.0,>=0.11.0->llama_index.embeddings.huggingface) (2.23.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from requests->huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama_index.embeddings.huggingface) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from requests->huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama_index.embeddings.huggingface) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from requests->huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama_index.embeddings.huggingface) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from requests->huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama_index.embeddings.huggingface) (2024.6.2)
# Requirement already satisfied: greenlet!=0.4.17 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.12.0,>=0.11.0->llama_index.embeddings.huggingface) (3.0.1)
# Requirement already satisfied: sympy in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers>=2.6.1->llama_index.embeddings.huggingface) (1.12)
# Requirement already satisfied: jinja2 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers>=2.6.1->llama_index.embeddings.huggingface) (3.1.4)
# Requirement already satisfied: setuptools in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers>=2.6.1->llama_index.embeddings.huggingface) (69.5.1)
# Requirement already satisfied: safetensors>=0.4.1 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from transformers<5.0.0,>=4.38.0->sentence-transformers>=2.6.1->llama_index.embeddings.huggingface) (0.4.5)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from transformers<5.0.0,>=4.38.0->sentence-transformers>=2.6.1->llama_index.embeddings.huggingface) (0.20.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from typing-inspect>=0.8.0->llama-index-core<0.12.0,>=0.11.0->llama_index.embeddings.huggingface) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from dataclasses-json->llama-index-core<0.12.0,>=0.11.0->llama_index.embeddings.huggingface) (3.22.0)
# Requirement already satisfied: anyio in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from httpx->llama-index-core<0.12.0,>=0.11.0->llama_index.embeddings.huggingface) (4.2.0)
# Requirement already satisfied: httpcore==1.* in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from httpx->llama-index-core<0.12.0,>=0.11.0->llama_index.embeddings.huggingface) (1.0.6)
# Requirement already satisfied: sniffio in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from httpx->llama-index-core<0.12.0,>=0.11.0->llama_index.embeddings.huggingface) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from httpcore==1.*->httpx->llama-index-core<0.12.0,>=0.11.0->llama_index.embeddings.huggingface) (0.14.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from scikit-learn->sentence-transformers>=2.6.1->llama_index.embeddings.huggingface) (2.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from jinja2->torch>=1.11.0->sentence-transformers>=2.6.1->llama_index.embeddings.huggingface) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from sympy->torch>=1.11.0->sentence-transformers>=2.6.1->llama_index.embeddings.huggingface) (1.3.0)
# Requirement already satisfied: llama-index-llms-huggingface in /opt/homebrew/anaconda3/lib/python3.12/site-packages (0.3.4)
# Requirement already satisfied: huggingface-hub<0.24.0,>=0.23.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from llama-index-llms-huggingface) (0.23.5)
# Requirement already satisfied: llama-index-core<0.12.0,>=0.11.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from llama-index-llms-huggingface) (0.11.16)
# Requirement already satisfied: text-generation<0.8.0,>=0.7.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from llama-index-llms-huggingface) (0.7.0)
# Requirement already satisfied: torch<3.0.0,>=2.1.2 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from llama-index-llms-huggingface) (2.4.1)
# Requirement already satisfied: transformers<5.0.0,>=4.37.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from transformers[torch]<5.0.0,>=4.37.0->llama-index-llms-huggingface) (4.45.1)
# Requirement already satisfied: filelock in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from huggingface-hub<0.24.0,>=0.23.0->llama-index-llms-huggingface) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from huggingface-hub<0.24.0,>=0.23.0->llama-index-llms-huggingface) (2024.3.1)
# Requirement already satisfied: packaging>=20.9 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from huggingface-hub<0.24.0,>=0.23.0->llama-index-llms-huggingface) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from huggingface-hub<0.24.0,>=0.23.0->llama-index-llms-huggingface) (6.0.1)
# Requirement already satisfied: requests in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from huggingface-hub<0.24.0,>=0.23.0->llama-index-llms-huggingface) (2.32.2)
# Requirement already satisfied: tqdm>=4.42.1 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from huggingface-hub<0.24.0,>=0.23.0->llama-index-llms-huggingface) (4.66.4)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from huggingface-hub<0.24.0,>=0.23.0->llama-index-llms-huggingface) (4.11.0)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-huggingface) (2.0.30)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-huggingface) (3.9.5)
# Requirement already satisfied: dataclasses-json in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-huggingface) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-huggingface) (1.2.14)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-huggingface) (1.0.8)
# Requirement already satisfied: httpx in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-huggingface) (0.27.2)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-huggingface) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-huggingface) (3.2.1)
# Requirement already satisfied: nltk>3.8.1 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-huggingface) (3.9.1)
# Requirement already satisfied: numpy<2.0.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-huggingface) (1.26.4)
# Requirement already satisfied: pillow>=9.0.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-huggingface) (10.3.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-huggingface) (2.9.2)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.2.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-huggingface) (8.2.2)
# Requirement already satisfied: tiktoken>=0.3.3 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-huggingface) (0.8.0)
# Requirement already satisfied: typing-inspect>=0.8.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-huggingface) (0.9.0)
# Requirement already satisfied: wrapt in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-huggingface) (1.14.1)
# Requirement already satisfied: sympy in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from torch<3.0.0,>=2.1.2->llama-index-llms-huggingface) (1.12)
# Requirement already satisfied: jinja2 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from torch<3.0.0,>=2.1.2->llama-index-llms-huggingface) (3.1.4)
# Requirement already satisfied: setuptools in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from torch<3.0.0,>=2.1.2->llama-index-llms-huggingface) (69.5.1)
# Requirement already satisfied: regex!=2019.12.17 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from transformers<5.0.0,>=4.37.0->transformers[torch]<5.0.0,>=4.37.0->llama-index-llms-huggingface) (2023.10.3)
# Requirement already satisfied: safetensors>=0.4.1 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from transformers<5.0.0,>=4.37.0->transformers[torch]<5.0.0,>=4.37.0->llama-index-llms-huggingface) (0.4.5)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from transformers<5.0.0,>=4.37.0->transformers[torch]<5.0.0,>=4.37.0->llama-index-llms-huggingface) (0.20.0)
# Requirement already satisfied: accelerate>=0.26.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from transformers[torch]<5.0.0,>=4.37.0->llama-index-llms-huggingface) (0.34.2)
# Requirement already satisfied: psutil in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from accelerate>=0.26.0->transformers[torch]<5.0.0,>=4.37.0->llama-index-llms-huggingface) (5.9.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-huggingface) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-huggingface) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-huggingface) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-huggingface) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-huggingface) (1.9.3)
# Requirement already satisfied: click in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from nltk>3.8.1->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-huggingface) (8.1.7)
# Requirement already satisfied: joblib in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from nltk>3.8.1->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-huggingface) (1.4.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.0->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-huggingface) (0.6.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.0->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-huggingface) (2.23.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from requests->huggingface-hub<0.24.0,>=0.23.0->llama-index-llms-huggingface) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from requests->huggingface-hub<0.24.0,>=0.23.0->llama-index-llms-huggingface) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from requests->huggingface-hub<0.24.0,>=0.23.0->llama-index-llms-huggingface) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from requests->huggingface-hub<0.24.0,>=0.23.0->llama-index-llms-huggingface) (2024.6.2)
# Requirement already satisfied: greenlet!=0.4.17 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-huggingface) (3.0.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from typing-inspect>=0.8.0->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-huggingface) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from dataclasses-json->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-huggingface) (3.22.0)
# Requirement already satisfied: anyio in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from httpx->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-huggingface) (4.2.0)
# Requirement already satisfied: httpcore==1.* in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from httpx->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-huggingface) (1.0.6)
# Requirement already satisfied: sniffio in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from httpx->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-huggingface) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from httpcore==1.*->httpx->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-huggingface) (0.14.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from jinja2->torch<3.0.0,>=2.1.2->llama-index-llms-huggingface) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from sympy->torch<3.0.0,>=2.1.2->llama-index-llms-huggingface) (1.3.0)
# Requirement already satisfied: llama-index-llms-groq in /opt/homebrew/anaconda3/lib/python3.12/site-packages (0.2.0)
# Requirement already satisfied: llama-index-core<0.12.0,>=0.11.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from llama-index-llms-groq) (0.11.16)
# Requirement already satisfied: llama-index-llms-openai-like<0.3.0,>=0.2.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from llama-index-llms-groq) (0.2.0)
# Requirement already satisfied: PyYAML>=6.0.1 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-groq) (6.0.1)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-groq) (2.0.30)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-groq) (3.9.5)
# Requirement already satisfied: dataclasses-json in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-groq) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-groq) (1.2.14)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-groq) (1.0.8)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-groq) (2024.3.1)
# Requirement already satisfied: httpx in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-groq) (0.27.2)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-groq) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-groq) (3.2.1)
# Requirement already satisfied: nltk>3.8.1 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-groq) (3.9.1)
# Requirement already satisfied: numpy<2.0.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-groq) (1.26.4)
# Requirement already satisfied: pillow>=9.0.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-groq) (10.3.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-groq) (2.9.2)
# Requirement already satisfied: requests>=2.31.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-groq) (2.32.2)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.2.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-groq) (8.2.2)
# Requirement already satisfied: tiktoken>=0.3.3 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-groq) (0.8.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-groq) (4.66.4)
# Requirement already satisfied: typing-extensions>=4.5.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-groq) (4.11.0)
# Requirement already satisfied: typing-inspect>=0.8.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-groq) (0.9.0)
# Requirement already satisfied: wrapt in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-groq) (1.14.1)
# Requirement already satisfied: llama-index-llms-openai<0.3.0,>=0.2.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from llama-index-llms-openai-like<0.3.0,>=0.2.0->llama-index-llms-groq) (0.2.11)
# Requirement already satisfied: transformers<5.0.0,>=4.37.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from llama-index-llms-openai-like<0.3.0,>=0.2.0->llama-index-llms-groq) (4.45.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-groq) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-groq) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-groq) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-groq) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-groq) (1.9.3)
# Requirement already satisfied: openai<2.0.0,>=1.40.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from llama-index-llms-openai<0.3.0,>=0.2.0->llama-index-llms-openai-like<0.3.0,>=0.2.0->llama-index-llms-groq) (1.51.0)
# Requirement already satisfied: click in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from nltk>3.8.1->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-groq) (8.1.7)
# Requirement already satisfied: joblib in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from nltk>3.8.1->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-groq) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from nltk>3.8.1->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-groq) (2023.10.3)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.0->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-groq) (0.6.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.0->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-groq) (2.23.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from requests>=2.31.0->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-groq) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from requests>=2.31.0->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-groq) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from requests>=2.31.0->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-groq) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from requests>=2.31.0->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-groq) (2024.6.2)
# Requirement already satisfied: greenlet!=0.4.17 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-groq) (3.0.1)
# Requirement already satisfied: filelock in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from transformers<5.0.0,>=4.37.0->llama-index-llms-openai-like<0.3.0,>=0.2.0->llama-index-llms-groq) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from transformers<5.0.0,>=4.37.0->llama-index-llms-openai-like<0.3.0,>=0.2.0->llama-index-llms-groq) (0.23.5)
# Requirement already satisfied: packaging>=20.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from transformers<5.0.0,>=4.37.0->llama-index-llms-openai-like<0.3.0,>=0.2.0->llama-index-llms-groq) (23.2)
# Requirement already satisfied: safetensors>=0.4.1 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from transformers<5.0.0,>=4.37.0->llama-index-llms-openai-like<0.3.0,>=0.2.0->llama-index-llms-groq) (0.4.5)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from transformers<5.0.0,>=4.37.0->llama-index-llms-openai-like<0.3.0,>=0.2.0->llama-index-llms-groq) (0.20.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from typing-inspect>=0.8.0->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-groq) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from dataclasses-json->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-groq) (3.22.0)
# Requirement already satisfied: anyio in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from httpx->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-groq) (4.2.0)
# Requirement already satisfied: httpcore==1.* in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from httpx->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-groq) (1.0.6)
# Requirement already satisfied: sniffio in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from httpx->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-groq) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from httpcore==1.*->httpx->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-groq) (0.14.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from openai<2.0.0,>=1.40.0->llama-index-llms-openai<0.3.0,>=0.2.0->llama-index-llms-openai-like<0.3.0,>=0.2.0->llama-index-llms-groq) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from openai<2.0.0,>=1.40.0->llama-index-llms-openai<0.3.0,>=0.2.0->llama-index-llms-openai-like<0.3.0,>=0.2.0->llama-index-llms-groq) (0.5.0)
# Requirement already satisfied: gradio in /opt/homebrew/anaconda3/lib/python3.12/site-packages (4.44.1)
# Requirement already satisfied: aiofiles<24.0,>=22.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from gradio) (23.2.1)
# Requirement already satisfied: anyio<5.0,>=3.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from gradio) (4.2.0)
# Requirement already satisfied: fastapi<1.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from gradio) (0.115.0)
# Requirement already satisfied: ffmpy in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from gradio) (0.4.0)
# Requirement already satisfied: gradio-client==1.3.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from gradio) (1.3.0)
# Requirement already satisfied: httpx>=0.24.1 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from gradio) (0.27.2)
# Requirement already satisfied: huggingface-hub>=0.19.3 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from gradio) (0.23.5)
# Requirement already satisfied: importlib-resources<7.0,>=1.3 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from gradio) (6.4.5)
# Requirement already satisfied: jinja2<4.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from gradio) (3.1.4)
# Requirement already satisfied: markupsafe~=2.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from gradio) (2.1.3)
# Requirement already satisfied: matplotlib~=3.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from gradio) (3.8.4)
# Requirement already satisfied: numpy<3.0,>=1.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from gradio) (1.26.4)
# Requirement already satisfied: orjson~=3.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from gradio) (3.10.7)
# Requirement already satisfied: packaging in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from gradio) (23.2)
# Requirement already satisfied: pandas<3.0,>=1.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from gradio) (2.2.2)
# Requirement already satisfied: pillow<11.0,>=8.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from gradio) (10.3.0)
# Requirement already satisfied: pydantic>=2.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from gradio) (2.9.2)
# Requirement already satisfied: pydub in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from gradio) (0.25.1)
# Requirement already satisfied: python-multipart>=0.0.9 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from gradio) (0.0.12)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from gradio) (6.0.1)
# Requirement already satisfied: ruff>=0.2.2 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from gradio) (0.6.9)
# Requirement already satisfied: semantic-version~=2.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from gradio) (2.10.0)
# Requirement already satisfied: tomlkit==0.12.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from gradio) (0.12.0)
# Requirement already satisfied: typer<1.0,>=0.12 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from gradio) (0.12.5)
# Requirement already satisfied: typing-extensions~=4.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from gradio) (4.11.0)
# Requirement already satisfied: urllib3~=2.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from gradio) (2.2.2)
# Requirement already satisfied: uvicorn>=0.14.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from gradio) (0.31.0)
# Requirement already satisfied: fsspec in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from gradio-client==1.3.0->gradio) (2024.3.1)
# Requirement already satisfied: websockets<13.0,>=10.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from gradio-client==1.3.0->gradio) (12.0)
# Requirement already satisfied: idna>=2.8 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from anyio<5.0,>=3.0->gradio) (3.7)
# Requirement already satisfied: sniffio>=1.1 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from anyio<5.0,>=3.0->gradio) (1.3.0)
# Requirement already satisfied: starlette<0.39.0,>=0.37.2 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from fastapi<1.0->gradio) (0.38.6)
# Requirement already satisfied: certifi in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from httpx>=0.24.1->gradio) (2024.6.2)
# Requirement already satisfied: httpcore==1.* in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from httpx>=0.24.1->gradio) (1.0.6)
# Requirement already satisfied: h11<0.15,>=0.13 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.24.1->gradio) (0.14.0)
# Requirement already satisfied: filelock in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from huggingface-hub>=0.19.3->gradio) (3.13.1)
# Requirement already satisfied: requests in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from huggingface-hub>=0.19.3->gradio) (2.32.2)
# Requirement already satisfied: tqdm>=4.42.1 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from huggingface-hub>=0.19.3->gradio) (4.66.4)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from matplotlib~=3.0->gradio) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from matplotlib~=3.0->gradio) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from matplotlib~=3.0->gradio) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from matplotlib~=3.0->gradio) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from matplotlib~=3.0->gradio) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from matplotlib~=3.0->gradio) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from pandas<3.0,>=1.0->gradio) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from pandas<3.0,>=1.0->gradio) (2023.3)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from pydantic>=2.0->gradio) (0.6.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from pydantic>=2.0->gradio) (2.23.4)
# Requirement already satisfied: click>=8.0.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from typer<1.0,>=0.12->gradio) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from typer<1.0,>=0.12->gradio) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from typer<1.0,>=0.12->gradio) (13.3.5)
# Requirement already satisfied: six>=1.5 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib~=3.0->gradio) (1.16.0)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (2.15.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from requests->huggingface-hub>=0.19.3->gradio) (2.0.4)
# Requirement already satisfied: mdurl~=0.1 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich>=10.11.0->typer<1.0,>=0.12->gradio) (0.1.0)

# %%
#import nest_asyncio

#nest_asyncio.apply()

# %%
import os

# Check if notebook is running on Google Colab
RunningInCOLAB = 'google.colab' in str(get_ipython())
if RunningInCOLAB:
    from google.colab import userdata
    print("Running on Google Colab")
    os.environ["GROQ_API_KEY"] = userdata.get('GROQ_API_KEY')
    os.environ["HF_TOKEN"] = userdata.get('HF_TOKEN')

# %% [markdown]
# ## 2. Load LLMs

# %%
from llama_index.core import PromptTemplate
from prompts import rag_system_prompt

# This will wrap the default prompts that are internal to llama-index
query_wrapper_prompt = PromptTemplate("<|USER|>{query_str}<|ASSISTANT|>")

# %% [markdown]
# ## 3. Create a Custom Router
#
# User's query will be classified into one of the following categories:
# - summary
# - retrieve
# - generation

# %% [markdown]
# **Question Examples**

# %%
questions = [
    "Who are you?",
    "How are you doing today?",
    "What is a Brute Force Attack?",
    "What kind of log file is this?",
    "Summarize the log.",
    "What does each column in this log mean?", #"What does each column mean in this log?",
    "Are there any abnormal activities?",
    "Show the abnormal activities.",
    "Identify the main anomaly activities.",
    "What happened at 03:28:22?",
    "What happened at '03:28:22'?",
    "What is 'combo' in this log?",
    "How many times does 'ALERT' occur in the log file?",
    "How many times did the user login?",
    "Which users have tried to log on to the FTP server?",
    "What is the event Event5?",
    "Which users are trying to log on in the event of an Event7?",
    "Which IP addresses are trying to log in for an Event7?",
]

# %% [markdown]
# # Create A Chatbot With Gradio

# %%
from types import resolve_bases
import re
import gradio as gr
from pathlib import Path
import threading
import time
from utils import get_query_engines, process_response, get_event_logs
from query import query_with_engines, generate_questions
from parser import retry_log_parsing
import json
from datetime import datetime


query_engines = None

# Initialize messages as a list with a system prompt
messages = [{"role": "system", "content": rag_system_prompt}]
stop_event = threading.Event()

def save_conversation(conversation, response_time, extra_info):
    if not conversation:
        print("No conversation to save.")
        return
    else:
        print(f"Saving conversation... {conversation}")

    timestamp = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
    conversation_data = [
        {
            "user_input": conversation[0],
            "response": conversation[1],
            "extra_info": extra_info,
            "timestamp": timestamp,
            "response_time": f"{response_time:.2f} seconds"
        }
    ]

    try:
        with open("conversation.json", "r+") as f:
            try:
                existing_data = json.load(f)
            except json.JSONDecodeError as e:
                print(f"Error parsing JSON: {str(e)}")
                existing_data = []
            except Exception as e:
                print(f"Unexpected error: {str(e)}")
                return
    except FileNotFoundError:
        existing_data = []

    existing_data.extend(conversation_data)

    try:
        with open("conversation.json", "w") as f:
            json.dump(existing_data, f, indent=4)
    except Exception as e:
        print(f"Error saving conversation: {str(e)}")

def print_like_dislike(x: gr.LikeData):
    # Print like/dislike data
    print(x.index, x.value, x.liked)

def add_message(message, history):
    global messages
    if history is None:
        history = []
    if message is not None and message != "":
        messages.append({"role": 'user', 'content': message})
        history.append((message, None))
    return "", "", history

def bot(history):
    global messages
    start_time = time.time()
    stop_event.clear()  # Clear any previous stop event
    if query_engines is None:
        gr.Warning("Warning: Please upload a log file first.")
        return history

    # Get the last message from the history
    if history is None or len(history) == 0:
        gr.Warning("Warning: Please enter a message.")
    else:
        text = history[-1][0]
        choice, response, context = query_with_engines(text, query_engines)
        for res in process_response(response):
            if stop_event.is_set():
                print("Stopping the bot response generation.")
                break
            history[-1][1] = res
            yield history
    # Print the last message and response
    print(history[-1][1])

    #template_ids = re.findall(r'\b[0-9a-f]{8}\b', history[-1][1])
    template_ids = re.findall(r'\bEvent\d+\b', history[-1][1])

    if template_ids:
      template_ids = list(dict.fromkeys(template_ids))
      print("Template IDs found:", template_ids)
    else:
      print("No template IDs found.")

    end_time = time.time()

    keywords = context.get('keywords') if context else None
    events = context.get('events') if context else None

    # Router + Time taken + Tokens/second

    extra_info = (f"\n> <sub><sup> **Route**: {choice.title()} </sup></sub>"
        f"{'' if not keywords else f'&nbsp;&nbsp;&nbsp;<sub><sup>🔑 **Keywords**: {keywords}</sup></sub>'}"
        f"{'' if not events else f'&nbsp;&nbsp;&nbsp;<sub><sup>🔑 **Events**: {events}</sup></sub>'}"
        f"&nbsp;&nbsp;&nbsp;<sub><sup>⏰ **Time Taken**: {end_time - start_time:.2f} s</sup></sub>"
        f"&nbsp;&nbsp;&nbsp;<sub><sup>✍ **Tokens/Second**: {len(history[-1][1]) / (end_time - start_time):.2f}</sup></sub>"
    )

    # Node info
    if hasattr(response, 'source_nodes') and len(response.source_nodes) > 0:
        print("Length of source_nodes:", len(response.source_nodes))
        extra_info += (
            f"&nbsp;&nbsp;&nbsp;<sub><sup>🔗 **Source Nodes**: {len(response.source_nodes)}</sup></sub>"
            f"\n<details>"
            f"\n<summary><sub><sup>📖 Show Nodes</sup></sub></summary>"
            "\n\n```js\n"
            + "\n".join([f"Node ID: {node.node_id}\n{node.get_text()}\n" for node in response.source_nodes])
            + "\n```\n</details>"
        )

    # Context
    if context and context.get('context'):
        extra_info += (
            f"&nbsp;&nbsp;&nbsp;<sub><sup>🔎 **Context**: {len(context['context'])}</sup></sub>"
            f"\n<details>"
            f"\n<summary><sub><sup>🔎 Show Context</sup></sub></summary>"
            "\n\n```txt\n"
            + "\n".join([f"{line.strip()}" for line in context['context']])
            + "\n```\n</details>"
        )


    # Get logs from with template_ids[0]
    event_log_dict = get_event_logs(query_engines, template_ids)
    #for event_id, logs in event_log_dict.items():
    #    print(f"EventId: {event_id}, Logs: {logs}")

    # Template info
    for template_id in template_ids:
        if template_id in event_log_dict:
            extra_info += (
                f"\n<details>"
                f"\n<summary><sub><sup>📝 Show Logs for Event: {template_id}</sup></sub></summary>"
                "\n\n```js\n"
                + "\n".join([f"{log_line}" for log_line in event_log_dict[template_id]])
                + "\n```\n</details>"
            )


    # Append extra info to the last message
    history[-1][1] += extra_info
    yield history
    response_time = end_time - start_time
    print(f"Time taken : {response_time:.2f} seconds.")
    save_conversation(history[-1], response_time, extra_info)


def first_bot(history):
    global messages
    global query_engines
    start_time = time.time()
    stop_event.clear()  # Clear any previous stop event
    if query_engines is None:
        gr.Warning("Warning: Please upload a log file first.")
        return history

    log_path = query_engines["log_path"]
    print(f"log_path: {log_path}")

    # log parsing
    current_path = os.getcwd()
    output_dir = os.path.join(current_path, 'result')
    retry_log_parsing(log_path, output_dir)

    prompt = "Generate a summary and some possible questions that the user might ask for this log file."
    response = generate_questions(prompt , query_engines)
    #response = f"This is a test."
    #history.append((None, "response"))
    for res in process_response(response):
            if stop_event.is_set():
                print("Stopping the bot response generation.")
                break
            yield [(None, res)]

    end_time = time.time()
    response_time = end_time - start_time
    # Print the last message and response
    history.append((None, res))
    print(history[-1][1])
    print(f"Time taken : {response_time:.2f} seconds.")
    yield history
    save_conversation([prompt, history[-1][1]], response_time, "")


def retry(history):
    global messages
    # Set the stop event
    stop_event.set()
    time.sleep(1)
    input_text = ""
    if len(messages) > 1:
        messages.pop()
    if len(history) > 0:
        input_text = history[-1][0]
        history.pop()
    return history, input_text

def undo(history):
    global messages
    # Set the stop event
    stop_event.set()
    time.sleep(1)
    if len(messages) > 1:
        messages.pop()
    if len(history) > 0:
        history.pop()
    return history

def clear(history):
    global messages
    # Set the stop event
    stop_event.set()
    time.sleep(1)
    messages = [{"role": "system", "content": rag_system_prompt}]
    history = []
    return history

def stop():
    stop_event.set()
    time.sleep(1)
    print(f"Stopping the bot response generation.")
    gr.Warning("Warning: Stopped by user")

def upload_file(filepath):
    global query_engines
    start_time = time.time()
    if filepath is not None:
        name = Path(filepath).name
        print("File uploaded: ", name)
        query_engines = get_query_engines(filepath)
        gr.Info("File uploaded successfully, and you can now start chatting.")
        end_time = time.time()
        print(f"Time taken : {end_time - start_time:.2f} seconds.")
        node_text = f"Total Nodes <br>{len(query_engines['nodes'])} "
        html = f"<div style='text-align:center;width:100px;'>{node_text}</div>"
        content = open(filepath, "r").read()
        return [
                gr.File(filepath, visible=True, min_width=800),
                gr.HTML(value=html, visible=True),
                gr.Code(value=content, label="File Content", visible=True),

            ]
    else:
        print("No file uploaded.")
        return gr.File("", visible=False)

def insert_fre_q(question):
    print(question)
    return question

with gr.Blocks() as demo:
    gr.Markdown("## LLMLogAnalyser Chatbot")
    # tab 1 Chatbot
    with gr.Tab("Chatbot"):
        chatbot = gr.Chatbot(
            [],
            label="LLMLogAnalyser Chatbot",
            avatar_images=("https://static.vecteezy.com/system/resources/previews/002/592/172/non_2x/smile-emoji-pop-art-line-style-icon-free-vector.jpg",
                        "https://images.emojiterra.com/google/noto-emoji/unicode-15/bw/512px/1f916.png"),
            bubble_full_width=False,
            height="63vh",
            layout="bubble",
            show_copy_button=True,
            placeholder="### Hi I am a LLMLogAnalyser Chatbot! \n### I can help you analyze log files. \n### Please upload a log file above to get started.",
        )

        with gr.Row():
            retry_but = gr.Button("🔄 Retry", elem_id="retry", variant="secondary", size="small")
            undo_but = gr.Button("↩️ Undo", elem_id="undo", variant="secondary", size="small")
            clear_but = gr.Button("🗑️  Clear", elem_id="clear", variant="secondary", size="small")
            stop_but = gr.Button("🛑 Stop", elem_id="stop", variant="secondary", size="small")

        chat_input = gr.Textbox(lines=1, placeholder="Enter your question or select a frequent question below...", label="User Input")

        frequent_queries = gr.Dropdown(questions, label="Frequent Queries", info="These are the most frequently asked questions", allow_custom_value=True)

        retry_but.click(retry, inputs=chatbot, outputs=[chatbot, chat_input])
        undo_but.click(undo, inputs=chatbot, outputs=chatbot)
        clear_but.click(clear, inputs=chatbot, outputs=chatbot)
        stop_but.click(stop, inputs=None, outputs=None)

        #frequent_queries.change(insert_fre_q, inputs=frequent_queries, outputs=chat_input)
        fre_msg = frequent_queries.select(add_message, [frequent_queries, chatbot], [chat_input, frequent_queries, chatbot])
        fre_bot_msg = fre_msg.then(bot, chatbot, chatbot, api_name="bot_response")


        chat_msg = chat_input.submit(add_message, [chat_input, chatbot], [chat_input, frequent_queries, chatbot])
        bot_msg = chat_msg.then(bot, chatbot, chatbot, api_name="bot_response")

        chatbot.like(print_like_dislike, None, None)

    # tab 2
    with gr.Tab("Upload Log File"):
        with gr.Row():
            file_output = gr.File(label="Uploaded file", visible=False)
            node_text = gr.HTML(value="", visible=False)
            upload_button = gr.UploadButton("Upload a log file", file_count="single", file_types=["text"])
        with gr.Row():
            file_content = gr.Code(value="", label="File Content", visible=False)
        # Upload file
        upload_action = upload_button.upload(upload_file, upload_button, [file_output, node_text, file_content])
        #upload_action.then(add_message, [gr.Textbox(lines=1, value="This is a test", visible=False), chatbot], [chat_input, frequent_queries, chatbot])
        upload_action.then(first_bot, chatbot , chatbot, api_name="bot_response")

demo.queue()
demo.launch(share=True, debug=True)
# Out:
# Running on local URL:  http://127.0.0.1:7860
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Running on public URL: https://f7defadd978cef29de.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://f7defadd978cef29de.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# File uploaded:  Linux_20k.txt
# [SentenceSplitter] Total number of nodes: 695
# File saved to: /Users/peng/Documents/Curtin Uni/2024-Semester-1/COMP6016 Project in Computer Sci 2/workspace/LLMLog/notebooks/llama3_chatbot/modules/Linux_20k.txt
# Old 'result' folder cleared.
# Time taken : 39.56 seconds.
# log_path: /Users/peng/Documents/Curtin Uni/2024-Semester-1/COMP6016 Project in Computer Sci 2/workspace/LLMLog/notebooks/llama3_chatbot/modules/Linux_20k.txt
# Lines:
# Nov 20 01:41:58 combo kernel: Out of Memory: Killed process 15922 (httpd).
# Sep 19 05:57:41 combo smartd[1788]: smartd has fork()ed into background mode. New PID=1788.
# Nov 22 02:15:35 combo kernel: Out of Memory: Killed process 30803 (httpd).
# Dec  6 05:50:20 combo kernel: Out of Memory: Killed process 8960 (httpd).
# Nov  5 06:41:28 combo ftpd[11288]: connection from 84.57.172.16 (dslb-084-057-172-016.pools.arcor-ip.net) at Sat Nov  5 06:41:28 2005
# Oct  8 22:31:30 combo ftpd[7492]: connection from 64.34.92.187 () at Sat Oct  8 22:31:30 2005
# Aug 17 04:03:15 combo su(pam_unix)[19297]: session opened for user cyrus by (uid=0)
# Nov 21 03:32:18 combo kernel: Out of Memory: Killed process 26476 (httpd).
# Dec  2 09:31:47 combo kernel: Out of Memory: Killed process 20154 (httpd).
# Jul 22 09:27:24 combo ftpd[12288]: connection from 211.42.188.206 () at Fri Jul 22 09:27:24 2005
#
# Prompt: Categorize the provided log lines into one of the categories:['HDFS', 'Hadoop', 'Spark', 'Zookeeper', 'BGL', 'HPC', 'Thunderbird', 'Windows', 'Linux', 'Android', 'HealthApp', 'Apache', 'Proxifier', 'OpenSSH', 'OpenStack', 'Mac'], assuming those logs share a single category.
# Return a JSON object with a single key "category" without any preamble, special characters, or explanation.
#
# Log:
# Nov 20 01:41:58 combo kernel: Out of Memory: Killed process 15922 (httpd).
# Sep 19 05:57:41 combo smartd[1788]: smartd has fork()ed into background mode. New PID=1788.
# Nov 22 02:15:35 combo kernel: Out of Memory: Killed process 30803 (httpd).
# Dec  6 05:50:20 combo kernel: Out of Memory: Killed process 8960 (httpd).
# Nov  5 06:41:28 combo ftpd[11288]: connection from 84.57.172.16 (dslb-084-057-172-016.pools.arcor-ip.net) at Sat Nov  5 06:41:28 2005
# Oct  8 22:31:30 combo ftpd[7492]: connection from 64.34.92.187 () at Sat Oct  8 22:31:30 2005
# Aug 17 04:03:15 combo su(pam_unix)[19297]: session opened for user cyrus by (uid=0)
# Nov 21 03:32:18 combo kernel: Out of Memory: Killed process 26476 (httpd).
# Dec  2 09:31:47 combo kernel: Out of Memory: Killed process 20154 (httpd).
# Jul 22 09:27:24 combo ftpd[12288]: connection from 211.42.188.206 () at Fri Jul 22 09:27:24 2005
#
#
# {"category": "Linux"}
# Identified Category: Linux
# input_dir: /Users/peng/Documents/Curtin Uni/2024-Semester-1/COMP6016 Project in Computer Sci 2/workspace/LLMLog/notebooks/llama3_chatbot/modules
# output_dir: /Users/peng/Documents/Curtin Uni/2024-Semester-1/COMP6016 Project in Computer Sci 2/workspace/LLMLog/notebooks/llama3_chatbot/modules/result
# log_file_name:  Linux_20k.txt
# Parsing file: /Users/peng/Documents/Curtin Uni/2024-Semester-1/COMP6016 Project in Computer Sci 2/workspace/LLMLog/notebooks/llama3_chatbot/modules/Linux_20k.txt
# Total lines:  20000
# Processed 5.0% of log lines.
# Processed 10.0% of log lines.
# Processed 15.0% of log lines.
# Processed 20.0% of log lines.
# Processed 25.0% of log lines.
# Processed 30.0% of log lines.
# Processed 35.0% of log lines.
# Processed 40.0% of log lines.
# Processed 45.0% of log lines.
# Processed 50.0% of log lines.
# Processed 55.0% of log lines.
# Processed 60.0% of log lines.
# Processed 65.0% of log lines.
# Processed 70.0% of log lines.
# Processed 75.0% of log lines.
# Processed 80.0% of log lines.
# Processed 85.0% of log lines.
# Processed 90.0% of log lines.
# Processed 95.0% of log lines.
# Processed 100.0% of log lines.
# Parsing done. [Time taken: 0:00:00.957157]
# structured_log_path: /Users/peng/Documents/Curtin Uni/2024-Semester-1/COMP6016 Project in Computer Sci 2/workspace/LLMLog/notebooks/llama3_chatbot/modules/result/Linux_20k.txt_structured.csv, templates_path: /Users/peng/Documents/Curtin Uni/2024-Semester-1/COMP6016 Project in Computer Sci 2/workspace/LLMLog/notebooks/llama3_chatbot/modules/result/Linux_20k.txt_templates.csv
# log_length: 20000, structured_log_length: 20000
# Log parsing successful.
# new_summary_tmpl_str: You are a Log Analyst. Your goal is to answer questions as accurately as possible based on the instructions and context provided.
# Context information is below.
# ---------------------
# Log file name Linux_20k.txt
# All the events in this log file, which is a csv file, contain three columns: EventId,EventTemplate,Occurrences
# ['Event1,restart.,32\n', 'Event2,syslogd startup succeeded,6\n', 'Event3,klogd startup succeeded,6\n', 'Event4,"klogd 1.4.1, log source = /proc/kmsg started.",6\n', 'Event5,Linux version 2.6.5-1.358 (bhcompile@bugs.build.redhat.com) (gcc version 3.3.3 20040412 (Red Hat Linux 3.3.3-7)) #1 Sat May 8 <*> EDT 2004,6\n', 'Event6,BIOS-provided physical RAM map:,6\n', 'Event7,BIOS-e820: <*> - <*> <*>,30\n', 'Event8,126MB LOWMEM available.,6\n', 'Event9,zapping low mappings.,6\n', 'Event10,On node 0 totalpages: 32430,6\n', 'Event11,"DMA zone: 4096 pages, LIFO batch:1",6\n', 'Event12,"Normal zone: 28334 pages, LIFO batch:6",6\n', 'Event13,"HighMem zone: 0 pages, LIFO batch:1",6\n', 'Event14,DMI 2.3 present.,6\n', 'Event15,ACPI disabled because your bios is from 2000 and too old,6\n', 'Event16,You can enable it with acpi=force,6\n', 'Event17,Built 1 zonelists,6\n', 'Event18,irqbalance startup succeeded,6\n', 'Event19,Kernel command line: ro root=LABEL=/ rhgb quiet,6\n', 'Event20,mapped 4G/4G trampoline to ffff3000.,6\n', 'Event21,Initializing CPU#0,6\n', 'Event22,portmap startup succeeded,6\n', 'Event23,"CPU 0 irqstacks, hard=02345000 soft=02344000",6\n', 'Event24,PID hash table entries: 512 (order 9: 4096 bytes),6\n', 'Event25,Detected <*> MHz processor.,6\n', 'Event26,Using tsc for high-res timesource,6\n', 'Event27,Console: colour VGA+ 80x25,6\n', 'Event28,"Memory: 125312k/129720k available (1540k kernel code, 3860k reserved, 599k data, 144k init, 0k highmem)",6\n', 'Event29,Calibrating delay loop... <*> BogoMIPS,6\n', 'Event30,Security Scaffold v1.0.0 initialized,6\n', 'Event31,SELinux: Initializing.,6\n', 'Event32,SELinux: Starting in permissive mode,6\n', 'Event33,"There is already a security framework initialized, register_security failed.",6\n', 'Event34,Failure registering capabilities with the kernel,6\n', 'Event35,selinux_register_security: Registering secondary module capability,6\n', 'Event36,Capability LSM initialized,6\n', 'Event37,"Dentry cache hash table entries: 16384 (order: 4, 65536 bytes)",6\n', 'Event38,"Inode-cache hash table entries: 8192 (order: 3, 32768 bytes)",6\n', 'Event39,"Mount-cache hash table entries: 512 (order: 0, 4096 bytes)",6\n', 'Event40,Version 1.0.6 Starting,6\n', 'Event41,rpc.statd startup succeeded,6\n', 'Event42,"CPU: L1 I cache: 16K, L1 D cache: 16K",6\n', 'Event43,CPU: L2 cache: 256K,6\n', 'Event44,Intel machine check architecture supported.,6\n', 'Event45,CPU: Intel Pentium III (Coppermine) stepping 06,6\n', 'Event46,Enabling fast FPU save and restore... done.,6\n', 'Event47,Enabling unmasked SIMD FPU exception support... done.,6\n', "Event48,Checking 'hlt' instruction... OK.,6\n", 'Event49,POSIX conformance testing by UNIFIX,6\n', 'Event50,NET: Registered protocol family <*>,36\n', 'Event51,"PCI: PCI BIOS revision 2.10 entry at 0xfc0ce, last bus=1",6\n', 'Event52,PCI: Using configuration type 1,6\n', 'Event53,ACPI: Subsystem revision 20040326,6\n', 'Event54,ACPI: Interpreter disabled.,6\n', 'Event55,Linux Plug and Play Support v0.97 (c) Adam Belay,6\n', 'Event56,usbcore: registered new driver <*>,24\n', 'Event57,rpc.idmapd startup succeeded,6\n', 'Event58,ACPI: ACPI tables contain no PCI IRQ routing entries,6\n', 'Event59,PCI: Invalid ACPI-PCI IRQ routing table,6\n', 'Event60,Initializing random number generator: succeeded,6\n', 'Event61,PCI: Probing PCI hardware,6\n', 'Event62,PCI: Probing PCI hardware (bus 00),6\n', 'Event63,Transparent bridge - 0000:00:1e.0,6\n', 'Event64,PCI: Using IRQ router PIIX/ICH [8086/2410] at 0000:00:1f.0,6\n', 'Event65,apm: BIOS version 1.2 Flags 0x03 (Driver version 1.16ac),6\n', 'Event66,audit: initializing netlink socket (disabled),6\n', 'Event67,audit(1118297138.4294965368:0): initialized,1\n', 'Event68,"Total HugeTLB memory allocated, 0",6\n', 'Event69,Starting pcmcia: succeeded,6\n', 'Event70,VFS: Disk quotas dquot_6.5.1,6\n', 'Event71,"Dquot-cache hash table entries: 1024 (order 0, 4096 bytes)",6\n', 'Event72,SELinux: Registering netfilter hooks,6\n', 'E ...
# The first line of the log file: Jun  9 06:06:20 combo syslogd 1.4.1: restart.
# The Last line of the log file: Dec  6 12:20:15 combo udev[10044]: removing device node '/udev/vcsa4'
# ---------------------
# The log file contains 20000 lines
# There are 397 log events in the log file.
# The log period can be indicated in the first and last lines of the log file.
# Given the context information, answer the query.
# Query: Generate a summary and some possible questions that the user might ask for this log file.
# Answer:
# **Summary**
#
# The provided log file, Linux_20k.txt, appears to be a system log file from a Linux-based operating system. The log file contains 20,000 lines of text, spanning a log period from June 9 to December 6. There are 397 unique log events in the file, indicating a diverse range of system activities and events. The log file includes information about system startup and shutdown, process initiation and termination, network activity, and various system errors and warnings.
#
# **Possible Questions**
#
# Based on the context and content of the log file, the user might ask the following questions:
#
# 1. **System Uptime and Availability**: What is the system uptime and availability during the log period? Are there any significant downtime periods or errors that could impact system performance?
# 2. **Error Analysis**: What are the most common error types and frequencies in the log file? Are there any recurring errors that require attention or troubleshooting?
# 3. **Process and Service Management**: Which processes and services are started and stopped during the log period? Are there any issues with process crashes or hangs?
# 4. **Network Activity**: What is the nature of network activity during the log period? Are there any suspicious or unexpected network connections or errors?
# 5. **Security and Authentication**: Are there any security-related events or errors, such as authentication failures or unauthorized access attempts?
# 6. **System Resource Utilization**: How are system resources (e.g., CPU, memory, disk) utilized during the log period? Are there any resource-intensive processes or errors?
# 7. **System Configuration and Changes**: Are there any changes to system configuration or settings during the log period? Are these changes intentional or unexpected?
# 8. **Error Correlation and Root Cause Analysis**: Are there any correlations between different error types or events? What is the root cause of these errors, and how can they be addressed?
#
# These questions can help the user gain a deeper understanding of the system's behavior, identify potential issues, and optimize system performance and security.
# Time taken : 5.15 seconds.
# Saving conversation... ['Generate a summary and some possible questions that the user might ask for this log file.', "**Summary**\n\nThe provided log file, Linux_20k.txt, appears to be a system log file from a Linux-based operating system. The log file contains 20,000 lines of text, spanning a log period from June 9 to December 6. There are 397 unique log events in the file, indicating a diverse range of system activities and events. The log file includes information about system startup and shutdown, process initiation and termination, network activity, and various system errors and warnings.\n\n**Possible Questions**\n\nBased on the context and content of the log file, the user might ask the following questions:\n\n1. **System Uptime and Availability**: What is the system uptime and availability during the log period? Are there any significant downtime periods or errors that could impact system performance?\n2. **Error Analysis**: What are the most common error types and frequencies in the log file? Are there any recurring errors that require attention or troubleshooting?\n3. **Process and Service Management**: Which processes and services are started and stopped during the log period? Are there any issues with process crashes or hangs?\n4. **Network Activity**: What is the nature of network activity during the log period? Are there any suspicious or unexpected network connections or errors?\n5. **Security and Authentication**: Are there any security-related events or errors, such as authentication failures or unauthorized access attempts?\n6. **System Resource Utilization**: How are system resources (e.g., CPU, memory, disk) utilized during the log period? Are there any resource-intensive processes or errors?\n7. **System Configuration and Changes**: Are there any changes to system configuration or settings during the log period? Are these changes intentional or unexpected?\n8. **Error Correlation and Root Cause Analysis**: Are there any correlations between different error types or events? What is the root cause of these errors, and how can they be addressed?\n\nThese questions can help the user gain a deeper understanding of the system's behavior, identify potential issues, and optimize system performance and security."]
# --------------------------------------------------
# User: What happened at '12:48:49'?
# --------------------------------------------------
# router_query with  What happened at '12:48:49'?
# {"choice": "partial"}
# [Level 1 Router] Routing to 'partial' stage
# partial_router_query with  What happened at '12:48:49'?
# {"choice": "search", "keywords": ["12:48:49"]}
# [Level 2 Router: Partial] Routing to 'search' stage
# keywords: ['12:48:49']
# events: []
# Keywords: ['12:48:49']
# Length of search_result: 0
# Search result: []
# No search result, and try answering the question directly.
#
#       <|begin_of_text|><|start_header_id|>system<|end_header_id|>
#
#       You are a Log Analyst. Your goal is to answer questions as accurately as possible based on the instructions and context provided.<|eot_id|><|start_header_id|>user<|end_header_id|>
#
#       There are 0 lines were matched by keywords: ['12:48:49'].
#
# Focus on the total number if the user asks a question about how many.
# Context: []
# Question: What happened at '12:48:49'?.<|eot_id|><|start_header_id|>assistant<|end_header_id|>
#
# Time taken: 0.42 seconds.
# LLM: Time taken: 1.08 seconds.
# LLM: There are no log entries matching the time '12:48:49'.
# No template IDs found.
# templates_path exist: /Users/peng/Documents/Curtin Uni/2024-Semester-1/COMP6016 Project in Computer Sci 2/workspace/LLMLog/notebooks/llama3_chatbot/modules/result/Linux_20k.txt_structured.csv
# Time taken : 1.43 seconds.
# Saving conversation... ["What happened at '12:48:49'?", "There are no log entries matching the time '12:48:49'.\n> <sub><sup> **Route**: Partial > Search </sup></sub>&nbsp;&nbsp;&nbsp;<sub><sup>🔑 **Keywords**: ['12:48:49']</sup></sub>&nbsp;&nbsp;&nbsp;<sub><sup>⏰ **Time Taken**: 1.43 s</sup></sub>&nbsp;&nbsp;&nbsp;<sub><sup>✍ **Tokens/Second**: 37.77</sup></sub>"]
# --------------------------------------------------
# User: What happened at '03:28:22'?
# --------------------------------------------------
# router_query with  What happened at '03:28:22'?
# {"choice": "partial"}
# [Level 1 Router] Routing to 'partial' stage
# partial_router_query with  What happened at '03:28:22'?
# {"choice": "search", "keywords": ["03:28:22"]}
# [Level 2 Router: Partial] Routing to 'search' stage
# keywords: ['03:28:22']
# events: []
# Keywords: ['03:28:22']
# Length of search_result: 8
# Search result: ['Jun 11 03:28:22 combo ftpd[4301]: connection from 209.184.7.130 () at Sat Jun 11 03:28:22 2005', 'Jun 11 03:28:22 combo ftpd[4305]: connection from 209.184.7.130 () at Sat Jun 11 03:28:22 2005', 'Jun 11 03:28:22 combo ftpd[4304]: connection from 209.184.7.130 () at Sat Jun 11 03:28:22 2005', 'Jun 11 03:28:22 combo ftpd[4308]: connection from 209.184.7.130 () at Sat Jun 11 03:28:22 2005', 'Jun 11 03:28:22 combo ftpd[4303]: connection from 209.184.7.130 () at Sat Jun 11 03:28:22 2005', 'Jun 11 03:28:22 combo ftpd[4306]: connection from 209.184.7.130 () at Sat Jun 11 03:28:22 2005', 'Jun 11 03:28:22 combo ftpd[4302]: connection from 209.184.7.130 () at Sat Jun 11 03:28:22 2005', 'Jun 11 03:28:22 combo ftpd[4307]: connection from 209.184.7.130 () at Sat Jun 11 03:28:22 2005']
#
#       <|begin_of_text|><|start_header_id|>system<|end_header_id|>
#
#       You are a Log Analyst. Your goal is to answer questions as accurately as possible based on the instructions and context provided.<|eot_id|><|start_header_id|>user<|end_header_id|>
#
#       There are 8 lines were matched by keywords: ['03:28:22'].
#
# Focus on the total number if the user asks a question about how many.
# Context: ['Jun 11 03:28:22 combo ftpd[4301]: connection from 209.184.7.130 () at Sat Jun 11 03:28:22 2005', 'Jun 11 03:28:22 combo ftpd[4305]: connection from 209.184.7.130 () at Sat Jun 11 03:28:22 2005', 'Jun 11 03:28:22 combo ftpd[4304]: connection from 209.184.7.130 () at Sat Jun 11 03:28:22 2005', 'Jun 11 03:28:22 combo ftpd[4308]: connection from 209.184.7.130 () at Sat Jun 11 03:28:22 2005', 'Jun 11 03:28:22 combo ftpd[4303]: connection from 209.184.7.130 () at Sat Jun 11 03:28:22 2005', 'Jun 11 03:28:22 combo ftpd[4306]: connection from 209.184.7.130 () at Sat Jun 11 03:28:22 2005', 'Jun 11 03:28:22 combo ftpd[4302]: connection from 209.184.7.130 () at Sat Jun 11 03:28:22 2005', 'Jun 11 03:28:22 combo ftpd[4307]: connection from 209.184.7.130 () at Sat Jun 11 03:28:22 2005']
# Question: What happened at '03:28:22'?.<|eot_id|><|start_header_id|>assistant<|end_header_id|>
#
# Time taken: 0.40 seconds.
# LLM: Time taken: 1.31 seconds.
# LLM: At '03:28:22', 8 connections were made from IP address 209.184.7.130 to the FTP server, as indicated by 8 different ftpd processes ([4301], [4302], [4303], [4304], [4305], [4306], [4307], and [4308]).
# No template IDs found.
# templates_path exist: /Users/peng/Documents/Curtin Uni/2024-Semester-1/COMP6016 Project in Computer Sci 2/workspace/LLMLog/notebooks/llama3_chatbot/modules/result/Linux_20k.txt_structured.csv
# Time taken : 1.94 seconds.
# Saving conversation... ["What happened at '03:28:22'?", "At '03:28:22', 8 connections were made from IP address 209.184.7.130 to the FTP server, as indicated by 8 different ftpd processes ([4301], [4302], [4303], [4304], [4305], [4306], [4307], and [4308]).\n> <sub><sup> **Route**: Partial > Search </sup></sub>&nbsp;&nbsp;&nbsp;<sub><sup>🔑 **Keywords**: ['03:28:22']</sup></sub>&nbsp;&nbsp;&nbsp;<sub><sup>⏰ **Time Taken**: 1.94 s</sup></sub>&nbsp;&nbsp;&nbsp;<sub><sup>✍ **Tokens/Second**: 103.36</sup></sub>&nbsp;&nbsp;&nbsp;<sub><sup>🔎 **Context**: 8</sup></sub>\n<details>\n<summary><sub><sup>🔎 Show Context</sup></sub></summary>\n\n```txt\nJun 11 03:28:22 combo ftpd[4301]: connection from 209.184.7.130 () at Sat Jun 11 03:28:22 2005\nJun 11 03:28:22 combo ftpd[4305]: connection from 209.184.7.130 () at Sat Jun 11 03:28:22 2005\nJun 11 03:28:22 combo ftpd[4304]: connection from 209.184.7.130 () at Sat Jun 11 03:28:22 2005\nJun 11 03:28:22 combo ftpd[4308]: connection from 209.184.7.130 () at Sat Jun 11 03:28:22 2005\nJun 11 03:28:22 combo ftpd[4303]: connection from 209.184.7.130 () at Sat Jun 11 03:28:22 2005\nJun 11 03:28:22 combo ftpd[4306]: connection from 209.184.7.130 () at Sat Jun 11 03:28:22 2005\nJun 11 03:28:22 combo ftpd[4302]: connection from 209.184.7.130 () at Sat Jun 11 03:28:22 2005\nJun 11 03:28:22 combo ftpd[4307]: connection from 209.184.7.130 () at Sat Jun 11 03:28:22 2005\n```\n</details>"]

# %%
#import nest_asyncio

#nest_asyncio.apply()
